# %% [markdown]
# # Your Title Here
#
# **Your Name(s) Here**

# %% [markdown]
# ## Summary of Findings
#
# ### Introduction
# TODO
#
# ### Cleaning and EDA
# TODO
#
# ### Assessment of Missingness
# TODO
#
# ### Hypothesis Test
# TODO

# %% [markdown]
# ## Code

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Cleaning and EDA

# %%
# TODO

# %% [markdown]
# ### Assessment of Missingness

# %%
# TODO

# %% [markdown]
# ### Hypothesis Testing

# %%
# TODO
